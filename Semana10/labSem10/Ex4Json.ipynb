# %%
import tweepy
import json
#adicionando credenciais

twitter_keys = {
    'consumer_key':         'KEYS',
    'consumer_secret':      'KEYS',
    'access_token_key':      'KEYS',
    'access_token_secret':   'KEYS'
}

# %%
#configurando acesso a API
auth = tweepy.OAuth1UserHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])

api = tweepy.API(auth)

# %%
#Faz a chamada da sua timeline e imprime cada texto dos tweets
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# #ofertadodia
#
# Cadeira Gamer Gt Racer Preto e Vermelho
#
# De: R$ 999,00
# Por: R$ 897,00📌
#
# https://t.co/cspCkXk6E4
# SEGUUURAAAAA O TIMAOOOOOO VAMO COME O FLABUCETA
# primeiro que eu leio que quero que seja verdade https://t.co/DErQBdGgK5
# #ofertadodia
#
# Copo térmico de cerveja Stanley | 473ml
#
# De: R$ 179,00
# Por: R$ 136,96📌
#
# https://t.co/S37u4xPgPs
# #ofertadodia
#
# Toss a coin to your witcher!!!
# The Witcher - Box capa clássica
#
# De: R$ 399,90
# Por: R$ 263,40📌
#
# https://t.co/lOSepKJsTo
# #ofertadodia
#
# Mangá Demon Slayer - Kimetsu No Yaiba Vol. 1
#
# De: R$ 33,90
# Por: R$ 21,50📌
#
# https://t.co/Z1H5Xcl6dV
# #ofertadodia
#
# Versão ultimate!!!
# Marvel's Spider-Man: Miles Morales Edição Ultimate - PlayStation 5
#
# De: R$ 349,90… https://t.co/tjei6NfDPL
# #ofertadodia
#
# JOGÃO DO CRL ❤️❤️❤️❤️❤️❤️
#
# Marvel's Spider-Man: Miles Morales Edição Padrão - PlayStation 5
#
# De:R$ 24… https://t.co/Jyyh1jRNLj
# SAUDACOES CAPITAO NAO TEMHO EMOJI DE EXERCITO MAS SAUDACOES TE AMO CORINTHIANS https://t.co/Oa3ERrIV0D
# RT @mepegoumto: https://t.co/Dan9UTqv1X
# fiz aquela trend de beijar seu pet e ver a reação dele 😭💖🤧 https://t.co/vKTrForoS0
# so tenho essa semana de ferias pra curtir e depois a bosta da escola de novo 😢
# #16 Atravessando O Abismo
#
# Kindle: R$ 41,89
# Físico: R$ 44,10
#
# https://t.co/FKjxKLgBii https://t.co/Cweje7vtmI
# #15 Badass: Making Users Awesome (English Edition)
#
# Kindle: R$ 88,70
# Físico: R$ 191,79
#
# https://t.co/R7MlvwDekk https://t.co/pkJbWMNifz
# uma mensagem de esperança para o mundo, bom dia https://t.co/6zT8OUEXo9 https://t.co/joPtcnACEK
# defina ''best'' https://t.co/bdxcf6DAwC
# cheguei em casa AGORA
# Segunda  feira  Ednaldo Pereira https://t.co/sh08n9EBb3
# RT @shouldhaveaduck: https://t.co/hFWp69Vh5Q
# RT @amigoanormal: https://t.co/WJSiwppIud

# %%
status = public_tweets[0]
#convert to string
json_str = json.dumps(status._json)
#deserialise string into python object
parsed = json.loads(json_str)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Mon Jul 18 14:45:57 +0000 2022",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     0,
#                     12
#                 ],
#                 "text": "ofertadodia"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "amzn.to/3J1nG2l",
#                 "expanded_url": "https://amzn.to/3J1nG2l",
#                 "indices": [
#                     86,
#                     109
#                 ],
#                 "url": "https://t.co/cspCkXk6E4"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1549042796798980097,
#     "id_str": "1549042796798980097",
#     "in_reply_to_screen_name": "viderotulo",
#     "in_reply_to_status_id": 1549041210198999040,
#     "in_reply_to_status_id_str": "1549041210198999040",
#     "in_reply_to_user_id": 107271114,
#     "in_reply_to_user_id_str": "107271114",
#     "is_quote_status": false,
#     "lang": "pt",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "text": "#ofertadodia\n\nCadeira Gamer Gt Racer Preto e Vermelho\n\nDe: R$ 999,00\nPor: R$ 897,00\ud83d\udccc\n\nhttps://t.co/cspCkXk6E4",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Jan 22 01:37:25 +0000 2010",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Melhor ler antes de consumir \ud83c\udf6d \nadvogada que virou product owner, apaixonada por tech.\na que posta oportunidades para iniciantes e links de promo",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "viderotulo.com",
#                         "expanded_url": "http://viderotulo.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/dPuTDbSx7E"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 21769,
#         "follow_request_sent": false,
#         "followers_count": 14381,
#         "following": true,
#         "friends_count": 714,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 107271114,
#         "id_str": "107271114",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 85,
#         "location": "Santos, Brazil",
#         "name": "vane",
#         "notifications": false,
#         "profile_background_color": "59472F",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/107271114/1582727351",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1543696029438152704/pGBNijvH_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1543696029438152704/pGBNijvH_normal.jpg",
#         "profile_link_color": "ABB8C2",
#         "profile_sidebar_border_color": "000515",
#         "profile_sidebar_fill_color": "061127",
#         "profile_text_color": "827972",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "viderotulo",
#         "statuses_count": 33894,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/dPuTDbSx7E",
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
